# %%
import pandas as pd
import numpy as np

# %%
data_path = "../data/NYC_Accidents_2020.csv"
df = pd.read_csv(data_path, low_memory=False)

# (rows, columns)
df.shape
# Out:
# (74881, 29)

# %%
# quick peek at the data
df.head()
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE                    LOCATION   ON STREET NAME  \
# 0  8/29/2020   15:40:00     BRONX   10466.0  40.89210 -73.833760   POINT (-73.83376 40.8921)     PRATT AVENUE
# 1  8/29/2020   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914  POINT (-73.919914 40.6905)  BUSHWICK AVENUE
# 2  8/29/2020   18:20:00       NaN       NaN  40.81650 -73.946556  POINT (-73.946556 40.8165)         8 AVENUE
# 3  8/29/2020    0:00:00     BRONX   10459.0  40.82472 -73.892960  POINT (-73.89296 40.82472)              NaN
# 4  8/29/2020   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890  POINT (-73.93389 40.64989)              NaN
#
#   CROSS STREET NAME      OFF STREET NAME  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0     STRANG AVENUE                  NaN                          0                         0
# 1   PALMETTO STREET                  NaN                          2                         0
# ...

# %%
# confirm column names match the original column names
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'ON STREET NAME',
#        'CROSS STREET NAME', 'OFF STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
#        'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED',
#        'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5', 'COLLISION_ID', 'VEHICLE TYPE CODE 1',
#        'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
# confirm structure and types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74881 entries, 0 to 74880
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     74881 non-null  object
#  1   CRASH TIME                     74881 non-null  object
#  2   BOROUGH                        49140 non-null  object
#  3   ZIP CODE                       49134 non-null  float64
#  4   LATITUDE                       68935 non-null  float64
#  5   LONGITUDE                      68935 non-null  float64
#  6   LOCATION                       68935 non-null  object
#  7   ON STREET NAME                 55444 non-null  object
#  8   CROSS STREET NAME              35681 non-null  object
#  9   OFF STREET NAME                19437 non-null  object
#  10  NUMBER OF PERSONS INJURED      74881 non-null  int64
#  11  NUMBER OF PERSONS KILLED       74881 non-null  int64
# ...

# %%
# numeric summary to spot strange values that don't make sense
df.describe()
# Out:
#            ZIP CODE      LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# count  49134.000000  68935.000000  68935.000000               74881.000000              74881.000000
# mean   10913.681585     40.689825    -73.843376                   0.366555                  0.001923
# std      515.069483      1.233368      2.234881                   0.726178                  0.047609
# min    10000.000000      0.000000    -74.253006                   0.000000                  0.000000
# 25%    10458.000000     40.667076    -73.958680                   0.000000                  0.000000
# 50%    11210.000000     40.716885    -73.916850                   0.000000                  0.000000
# 75%    11354.000000     40.789445    -73.862630                   1.000000                  0.000000
# max    11697.000000     40.912884      0.000000                  15.000000                  4.000000
#
# ...

# %%
# missing values per column overview (%)
missing = (
    df.isna()
      .mean()
      .sort_values(ascending=False)
      .to_frame("missing_pct")
)

missing.head(15)
# Out:
#                                missing_pct
# VEHICLE TYPE CODE 5               0.993283
# CONTRIBUTING FACTOR VEHICLE 5     0.993016
# VEHICLE TYPE CODE 4               0.976349
# CONTRIBUTING FACTOR VEHICLE 4     0.975281
# VEHICLE TYPE CODE 3               0.914211
# CONTRIBUTING FACTOR VEHICLE 3     0.909657
# OFF STREET NAME                   0.740428
# CROSS STREET NAME                 0.523497
# ZIP CODE                          0.343839
# BOROUGH                           0.343759
# VEHICLE TYPE CODE 2               0.283690
# ON STREET NAME                    0.259572
# CONTRIBUTING FACTOR VEHICLE 2     0.208277
# LOCATION                          0.079406
# LONGITUDE                         0.079406

# %%
# Normalize column names: lowercase, snake case, strip whitespaces
df.columns = (
    df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ", "_")
      .str.replace(r"[^a-z0-9_]", "", regex=True)
)
df.columns.tolist()
# Out:
# ['crash_date',
#  'crash_time',
#  'borough',
#  'zip_code',
#  'latitude',
#  'longitude',
#  'location',
#  'on_street_name',
#  'cross_street_name',
#  'off_street_name',
#  'number_of_persons_injured',
#  'number_of_persons_killed',
#  'number_of_pedestrians_injured',
#  'number_of_pedestrians_killed',
#  'number_of_cyclist_injured',
#  'number_of_cyclist_killed',
#  'number_of_motorist_injured',
#  'number_of_motorist_killed',
#  'contributing_factor_vehicle_1',
#  'contributing_factor_vehicle_2',
#  'contributing_factor_vehicle_3',
#  'contributing_factor_vehicle_4',
#  'contributing_factor_vehicle_5',
#  'collision_id',
#  'vehicle_type_code_1',
#  'vehicle_type_code_2',
#  'vehicle_type_code_3',
#  'vehicle_type_code_4',
#  'vehicle_type_code_5']

# %%
# parse datetimes, create a combined crash datetime
df["crash_date"] = pd.to_datetime(df["crash_date"], format="%m/%d/%Y", errors="coerce")
df["crash_time"] = pd.to_datetime(df["crash_time"], format="%H:%M:%S", errors="coerce").dt.time

df["crash_datetime"] = pd.to_datetime(
    df["crash_date"].astype(str) + " " + df["crash_time"].astype(str),
    format="%Y-%m-%d %H:%M:%S",
    errors="coerce"
)

# %%
# columns to string
df["zip_code"] = df["zip_code"].astype("string")
df["collision_id"] = df["collision_id"].astype("string")

# create derived columns
df["hour"] = df["crash_datetime"].dt.hour
df["month"] = df["crash_date"].dt.month
df["month_name"] = df["crash_date"].dt.month_name()
df["day_of_week"] = df["crash_date"].dt.day_name()
df["is_weekend"] = df["day_of_week"].isin(["Saturday", "Sunday"])
df["is_fatal"] = df["number_of_persons_killed"] > 0

# drop redundant / sparse columns
cols_to_drop = [
    "crash_time",
    "location",
    "contributing_factor_vehicle_3",
    "contributing_factor_vehicle_4",
    "contributing_factor_vehicle_5",
    "vehicle_type_code_3",
    "vehicle_type_code_4",
    "vehicle_type_code_5",
]

df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74881 entries, 0 to 74880
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   crash_date                     74881 non-null  datetime64[ns]
#  1   borough                        49140 non-null  object
#  2   zip_code                       49134 non-null  string
#  3   latitude                       68935 non-null  float64
#  4   longitude                      68935 non-null  float64
#  5   on_street_name                 55444 non-null  object
#  6   cross_street_name              35681 non-null  object
#  7   off_street_name                19437 non-null  object
#  8   number_of_persons_injured      74881 non-null  int64
#  9   number_of_persons_killed       74881 non-null  int64
#  10  number_of_pedestrians_injured  74881 non-null  int64
#  11  number_of_pedestrians_killed   74881 non-null  int64
# ...

# %%
df[["crash_date", "month", "day_of_week", "hour", "is_fatal"]].head()
# Out:
#   crash_date  month day_of_week  hour  is_fatal
# 0 2020-08-29      8    Saturday    15     False
# 1 2020-08-29      8    Saturday    21     False
# 2 2020-08-29      8    Saturday    18     False
# 3 2020-08-29      8    Saturday     0     False
# 4 2020-08-29      8    Saturday    17     False

# %%
df[["month", "day_of_week", "hour"]].isna().mean()
# Out:
# month          0.0
# day_of_week    0.0
# hour           0.0
# dtype: float64
